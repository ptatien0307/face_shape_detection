# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Fri Nov 25 15:58:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   76C    P0    34W /  70W |   9272MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, utils, callbacks
from tensorflow.keras.applications import VGG16
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
from imutils import paths

# %% [markdown]
# # Load dataset

# %%
CATEGORIES = ['heart', 'oblong', 'oval', 'round', 'square']
epochs=50
batch_size = 32
IMG_SIZE = 224
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)

# %%
trainDS = utils.image_dataset_from_directory(
    '/content/drive/MyDrive/CS331/imageDropData/train',
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    color_mode='rgb',
)

testDS = utils.image_dataset_from_directory(
    '/content/drive/MyDrive/CS331/imageDropData/test',
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    color_mode='rgb',
)
# Out:
# Found 4000 files belonging to 5 classes.
# Found 1000 files belonging to 5 classes.

# %% [markdown]
# # Load pretrained model

# %%
preprocessInput = tf.keras.applications.vgg16.preprocess_input

baseModel = VGG16(input_shape=IMG_SHAPE,
              include_top=False,
              weights='imagenet')
baseModel.trainable = False

# %% [markdown]
# # Build model

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))

x = preprocessInput(inputs)
x = baseModel(x, training=False)
x = layers.Flatten()(x)
outputs = layers.Dense(5)(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_5   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_5 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 5)                 125445
#
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy']
)

# %%
checkpointPath = "/content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-{epoch:02d}-{val_accuracy:.2f}.h5"

# %%
modelEarlyStopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    min_delta=0.025,
    verbose=1,
    mode='auto',
    restore_best_weights=False,
)

modelCheckpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpointPath,
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose = 1,
    mode='max'
)

# %% [markdown]
# # Train model

# %%
with tf.device('/gpu:0'):
    history = model.fit(
            trainDS,
            validation_data=testDS,
            epochs=epochs,
            callbacks = [modelEarlyStopping, modelCheckpoint]
    )
# Out:
# Epoch 1/50
# 125/125 [==============================] - ETA: 0s - loss: 6.4297 - accuracy: 0.4527
# Epoch 1: val_accuracy improved from -inf to 0.52700, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-01-0.53.h5
# 125/125 [==============================] - 30s 230ms/step - loss: 6.4297 - accuracy: 0.4527 - val_loss: 5.9999 - val_accuracy: 0.5270
# Epoch 2/50
# 125/125 [==============================] - ETA: 0s - loss: 1.7835 - accuracy: 0.7638
# Epoch 2: val_accuracy improved from 0.52700 to 0.56400, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-02-0.56.h5
# 125/125 [==============================] - 28s 220ms/step - loss: 1.7835 - accuracy: 0.7638 - val_loss: 5.3517 - val_accuracy: 0.5640
# Epoch 3/50
# 125/125 [==============================] - ETA: 0s - loss: 1.0398 - accuracy: 0.8540
# Epoch 3: val_accuracy improved from 0.56400 to 0.57300, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-03-0.57.h5
# 125/125 [==============================] - 29s 225ms/step - loss: 1.0398 - accuracy: 0.8540 - val_loss: 5.5862 - val_accuracy: 0.5730
# Epoch 4/50
# 125/125 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.8992
# Epoch 4: val_accuracy improved from 0.57300 to 0.58000, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-04-0.58.h5
# 125/125 [==============================] - 28s 223ms/step - loss: 0.6265 - accuracy: 0.8992 - val_loss: 6.4204 - val_accuracy: 0.5800
# Epoch 5/50
# 125/125 [==============================] - ETA: 0s - loss: 0.3557 - accuracy: 0.9395
# Epoch 5: val_accuracy improved from 0.58000 to 0.58700, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-05-0.59.h5
# 125/125 [==============================] - 29s 226ms/step - loss: 0.3557 - accuracy: 0.9395 - val_loss: 6.2319 - val_accuracy: 0.5870
# Epoch 6/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9563
# Epoch 6: val_accuracy improved from 0.58700 to 0.59500, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-06-0.60.h5
# 125/125 [==============================] - 28s 222ms/step - loss: 0.2289 - accuracy: 0.9563 - val_loss: 6.2231 - val_accuracy: 0.5950
# Epoch 7/50
# 125/125 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9635
# Epoch 7: val_accuracy improved from 0.59500 to 0.60700, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-07-0.61.h5
# 125/125 [==============================] - 29s 228ms/step - loss: 0.1582 - accuracy: 0.9635 - val_loss: 6.6473 - val_accuracy: 0.6070
# Epoch 8/50
# 125/125 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9663
# Epoch 8: val_accuracy did not improve from 0.60700
# 125/125 [==============================] - 28s 220ms/step - loss: 0.1910 - accuracy: 0.9663 - val_loss: 6.6648 - val_accuracy: 0.5970
# Epoch 9/50
# 125/125 [==============================] - ETA: 0s - loss: 0.3725 - accuracy: 0.9423
# Epoch 9: val_accuracy improved from 0.60700 to 0.61100, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-09-0.61.h5
# 125/125 [==============================] - 28s 220ms/step - loss: 0.3725 - accuracy: 0.9423 - val_loss: 6.9858 - val_accuracy: 0.6110
# Epoch 10/50
# 125/125 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.9298
# Epoch 10: val_accuracy did not improve from 0.61100
# 125/125 [==============================] - 28s 222ms/step - loss: 0.4929 - accuracy: 0.9298 - val_loss: 8.6866 - val_accuracy: 0.5940
# Epoch 11/50
# 125/125 [==============================] - ETA: 0s - loss: 0.5308 - accuracy: 0.9348
# Epoch 11: val_accuracy improved from 0.61100 to 0.62700, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-11-0.63.h5
# 125/125 [==============================] - 29s 224ms/step - loss: 0.5308 - accuracy: 0.9348 - val_loss: 8.0368 - val_accuracy: 0.6270
# Epoch 12/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.9615
# Epoch 12: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 28s 221ms/step - loss: 0.2662 - accuracy: 0.9615 - val_loss: 8.9920 - val_accuracy: 0.6010
# Epoch 13/50
# 125/125 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9695
# Epoch 13: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 29s 223ms/step - loss: 0.1983 - accuracy: 0.9695 - val_loss: 9.5767 - val_accuracy: 0.5920
# Epoch 14/50
# 125/125 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9730
# Epoch 14: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 28s 221ms/step - loss: 0.1658 - accuracy: 0.9730 - val_loss: 8.3512 - val_accuracy: 0.6180
# Epoch 15/50
# 125/125 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9785
# Epoch 15: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 28s 220ms/step - loss: 0.1350 - accuracy: 0.9785 - val_loss: 9.1318 - val_accuracy: 0.6140
# Epoch 16/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9695
# Epoch 16: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 28s 223ms/step - loss: 0.2257 - accuracy: 0.9695 - val_loss: 9.9636 - val_accuracy: 0.5960
# Epoch 17/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9697
# Epoch 17: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 29s 224ms/step - loss: 0.2388 - accuracy: 0.9697 - val_loss: 10.2060 - val_accuracy: 0.5970
# Epoch 18/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9680
# Epoch 18: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 29s 224ms/step - loss: 0.2767 - accuracy: 0.9680 - val_loss: 10.0920 - val_accuracy: 0.6200
# Epoch 19/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.9685
# Epoch 19: val_accuracy did not improve from 0.62700
# 125/125 [==============================] - 28s 219ms/step - loss: 0.2891 - accuracy: 0.9685 - val_loss: 10.4049 - val_accuracy: 0.6170
# Epoch 20/50
# 125/125 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9695
# Epoch 20: val_accuracy improved from 0.62700 to 0.63700, saving model to /content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-20-0.64.h5
# 125/125 [==============================] - 30s 231ms/step - loss: 0.2165 - accuracy: 0.9695 - val_loss: 10.5861 - val_accuracy: 0.6370
# Epoch 21/50
# 125/125 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9750
# Epoch 21: val_accuracy did not improve from 0.63700
# 125/125 [==============================] - 28s 217ms/step - loss: 0.1937 - accuracy: 0.9750 - val_loss: 11.1363 - val_accuracy: 0.6200
# Epoch 21: early stopping

# %% [markdown]
# # Plot loss and accuracy

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Test model

# %%
def loadData(path):
    imagePaths = list(paths.list_images(path))
    data = []
    labels = []

    for imagePath in tqdm(imagePaths):
        label = imagePath.split(os.path.sep)[-2]
        # Read image
        image = cv2.imread(imagePath)

        # Resize
        imageResize = cv2.resize(image, (224,224))


        data.append(imageResize)
        labels.append(label)
    data = np.array(data)
    labels = np.array(labels)
    lb = LabelEncoder()
    labels = lb.fit_transform(labels)
    return data, labels

# %%
xTest, yTest = loadData(('/content/drive/MyDrive/CS331/imageDropData/test'))
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 180.59it/s]

# %%
newModel = keras.models.load_model('/content/drive/MyDrive/CS331/FaceOnly/VGG16/checkpoint/model-20-0.64.h5')

# %%
zScores = newModel.predict(xTest)
yPred = np.argmax(zScores, axis=1)
corrects = (yTest == yPred).sum()
print(f'Model predict {corrects}/{len(yTest)} corrects')
# Out:
# 32/32 [==============================] - 5s 167ms/step
# Model predict 507/1000 corrects

# %% [markdown]
# ## Confusion matrix

# %%
cm = tf.math.confusion_matrix(labels=yTest, predictions=yPred)
plt.figure(figsize=(5,5))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=['heart', 'oblong', 'oval', 'round', 'square'],
            yticklabels=['heart', 'oblong', 'oval', 'round', 'square'],
            )
plt.xticks(rotation=45)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.plot()
# Out:
# []

# %% [markdown]
# ## Classification report

# %%
print(classification_report(yTest, yPred,target_names=['heart', 'oblong', 'oval', 'round', 'square']))
# Out:
#               precision    recall  f1-score   support
#
#        heart       0.65      0.24      0.36       200
#       oblong       0.55      0.66      0.60       200
#         oval       0.38      0.65      0.48       200
#        round       0.61      0.53      0.57       200
#       square       0.61      0.52      0.56       200
#
#     accuracy                           0.52      1000
#    macro avg       0.56      0.52      0.51      1000
# weighted avg       0.56      0.52      0.51      1000
